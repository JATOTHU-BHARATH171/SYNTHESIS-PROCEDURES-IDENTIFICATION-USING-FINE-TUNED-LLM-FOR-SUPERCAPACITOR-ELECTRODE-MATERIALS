# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Out:
# Requirement already satisfied: wordcloud in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (1.9.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.6.1 in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (1.24.2)
# Requirement already satisfied: pillow in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sai vinay kumar\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# Create an empty list to store dataframes for each file
dfs = []

# Directory where your text files are located
text_files_dir = "E:\\B Tech project work\\Abstract"

# Loop through each text file in the directory
for filename in os.listdir(text_files_dir):
    if filename.endswith(".txt"):
        file_path = os.path.join(text_files_dir, filename)
        with open(file_path, "r", encoding="utf8") as file:
            content = file.read()
            df = pd.DataFrame({"File Name": [filename], "Content": [content]})
            dfs.append(df)

# Concatenate all dataframes into one
data = pd.concat(dfs, ignore_index=True)

# Save the DataFrame to an csv file
output_csv_file = "output_data.csv"
data.to_csv(output_csv_file, index=False)

print(f"Data has been saved to {output_csv_file}")
# Out:
# Data has been saved to output_data.csv

# %%
df = pd.read_csv("output_data.csv")
df.head()
# Out:
#     File Name                                            Content
# 0  01_abs.txt  While electrochemical water splitting is one o...
# 1  02_abs.txt   While electrochemical water splitting is one ...
# 2  03_abs.txt  In this work, we demonstrate an effective stra...
# 3  04_abs.txt  ZnO nanomaterials have attracted tremendous in...
# 4  05_abs.txt  The many applications of high energy storage d...

# %%
df.isna().sum()
# Out:
# File Name    0
# Content      7
# dtype: int64

# %%
df.dropna(subset=['Content'], inplace=True)

# %%
text = " ".join(cat.split()[1] for cat in df.Content)

# %%
stop_words = ["of", "the", "this", "paper", "are", "have", "with", "and", "to", "in", "we", "i", "review", "c", "report", "recent", "new", "power", "study", "we", "work", "like", "article"]

# %%
word_cloud = WordCloud(collocations = False, stopwords = stop_words, background_color = 'white', width=3200, height=1600).generate(text)

# %%
# plt.imshow(word_cloud, interpolation='bilinear')
# plt.axis("off")
# #plt.show()
# plt.savefig("wordcloud.png", format="png", dpi=300)

# %%
plt.figure(figsize = (8, 4), facecolor = None)
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad = 1.0)

# Saving the wordcloud
plt.savefig("wordcloud1.png", format="png", dpi=1200, pad_inches=0.1,)
plt.show()
